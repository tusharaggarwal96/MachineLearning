# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
data=pd.read_csv('./train.csv')
data.shape

data=data.values

# %%
label=np.zeros((42000,))
label=data[:,0]
data_x=np.zeros((42000,784))
data_x=data[:,1:]

def dist(x1,x2):
    return np.sqrt(((x1-x2)**2).sum())

plt.figure(0)
plt.imshow(data_x[1040].reshape((28,28)),cmap='gray')
plt.show()

# %%
idx=int((np.random.random())*data_x.shape[0])
print idx
# Out:
# 12566

# %%
def knn(X_train,q,Y_train,k):
    val=[]
    
    for ix in range(X_train.shape[0]):
        val.append([dist(q,X_train[ix,:]),Y_train[ix]])
    val=sorted(val,key=lambda x:x[0])
    pred_arr=np.asarray(val[:k])
    pred_arr=np.unique(pred_arr[:,1],return_counts=True)
    print pred_arr
    pred=pred_arr[1].argmax();
    return pred_arr[0][pred]
    #return
q=np.zeros((1,784))
q=data_x[idx,:]
knn(data_x[:10000],q,label[:10000],5)
print label[idx]        #checking the found label
# Out:
# (array([ 1.]), array([5], dtype=int64))
# 1.0
# 1
